# %% [markdown]
# ### Explain GET and POST methods.

# %% [raw]
# GET:
#
# case of GET request,only limites amount of data can be sent because data is sent in header.
#
# Get request is not secured because data is exposed in URL bar.
#
# Get request can be book marked.
#
# Get request is idempotent.
#
#  Get request is efficient and used more than post.

# %% [raw]
#  in case of post request,large amount of data can be sent because data is sent in body.
#
# POST request is secured because data is not secured in url.
#
# POST request cannot be bookmarked.
#
# post request is non idempotent.
#
# Post reduest is less effiecient.

# %% [markdown]
# ### Why is request used in Flask?

# %% [raw]
#  The Request, in Flask, is an object that contains all the data sent from the Client to Server. This data can be recovered using the GET/POST Methods

# %% [markdown]
# ### Why is redirect() used in Flask?

# %% [raw]
# Flask class has a redirect() function. When called, it returns a response object and redirects the user to another target location with specified status code. location parameter is the URL where response should be redirected.

# %% [markdown]
# ### What are templates in Flask? Why is the render_template() function used?

# %% [markdown]
# What are templates in Flask?
# Templates are files that contain static data as well as placeholders for dynamic data. A template is rendered with specific data to produce a final document. Flask uses the Jinja template library to render templates. In your application, you will use templates to render HTML which will display in the user's browser.
#
#
# render_template is a Flask function from the flask.templating package. render_template is used to generate output from a template file based on the Jinja2 engine that is found in the application's templates folder.
#
# Note that render_template is typically imported directly from the flask package instead of from flask.templating. It is the same function that is imported, but there are less characters to type when you leave off the .templating part.

# %% [markdown]
# ### Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.

# %% [raw]
# from flask import Flask,request,render_template,jsonify
#
# app=Flask(__name__)
#
# @app.route('/PMan',methods=['POST'])
#
# def math_op():
#
#     if (request.method=='POST'):
#         op=request.json['operation']
#         n1=request.json['n1']
#         n2=request.json['n2']
#
#         if op=='ADD':
#             r=n1+n2
#             result="sum of" +str(n1)+ "and" +str(n2) +"is"+ str(r)
#         if op=='DIFF':
#             r=n1-n2
#             result="diff of "+ str(n1) +"and"+ str(n2)+ "is"+ str(r)
#     return jsonify(result)
#
# if __name__==("__main__"):
#     app.run(host='0.0.0.0')

# %% [markdown]
# ![flask2.png](attachment:b30c87e1-0718-49c4-b392-5dbe18c95592.png)
