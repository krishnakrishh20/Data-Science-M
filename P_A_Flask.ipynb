# %% [markdown]
# ### Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [raw]
# Flask is a web framework, it’s a Python module that lets you develop web applications easily. It’s has a small and easy-to-extend core: it’s a microframework that doesn’t include an ORM (Object Relational Manager) or such features.
#
# It does have many cool features like url routing, template engine. It is a WSGI web app framework.
#
#
# Advantages:
#
# 1.Scalable
# 2.Flexible.
# 3.easy to Negotiate.
# 4.Lightweight

# %% [markdown]
# ### Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output inJupyter Notebook.

# %% [raw]
# from flask import Flask
#
# app = Flask(__name__)
#
# @app.route("/")
# def hello_world():
#     return "<h1>Hello, World!</h1>"
#
# if __name__=="__main__":
#     app.run(host="0.0.0.0")

# %% [markdown]
# ![2023-03-01.png](attachment:593770b8-5d48-43b6-a392-0e656e179859.png)

# %% [markdown]
# ### What is App routing in Flask? Why do we use app routes?

# %% [raw]
# App Routing means mapping the URLs to a specific function that will handle the logic for that URL. Modern web frameworks use more meaningful URLs to help users remember the URLs and make navigation simpler. Example: In our application, the URL (“/”) is associated with the root URL.
#
# What is app route used for?
# App routing is used to map the specific URL with the associated function that is intended to perform some task. It is used to access some particular page like Flask Tutorial in the web application.

# %% [markdown]
# ### Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# ### route to show the following details:
# ### Company Name: ABC Corporation
# ### Location: India
# ### Contact Detail: 999-999-9999

# %% [raw]
# from flask import Flask
#
# app = Flask(__name__)
#
# @app.route("/welcome")
# def test1():
#     return "<h1>Welcome to ABC Corporation</h1>"
# @app.route("/")
# def test2():
#     return"<h1>Company Name: ABC Corporation </h1>\n <h1>Location: India</h1>\n <h1>Contact Detail: 999-999-9999</h1>"
#
# if __name__=="__main__":
#     app.run(host="0.0.0.0")

# %% [markdown]
# ![flask1.png](attachment:9d92b09d-a0ab-489c-ad1c-233e1857f135.png)

# %% [markdown]
# ![flask2.png](attachment:6caec7f2-a789-487a-993f-dd4b83419ee3.png)

# %% [markdown]
# ### What function is used in Flask for URL Building? Write a Python code to demonstrate the working of theurl_for() function.

# %% [raw]
# To build a URL to a specific function, use the url_for() function. It accepts the name of the function as its first argument and any number of keyword arguments, each corresponding to a variable part of the URL rule.

# %% [raw]
# from flask import Flask,url_for
#
# appFlask = Flask(__name__)
# @appFlask.route('/home')
# def home():
#    return 'We are in Home Page!'
# with appFlask.test_request_context():
#     print(url_for('home'))
#
# if __name__=="__main__":
#     appFlask.run(host="0.0.0.0")

# %% [markdown]
# ![2023-03-01 (3).png](attachment:856c61d4-7857-4066-9e4c-115b0584e34c.png)
